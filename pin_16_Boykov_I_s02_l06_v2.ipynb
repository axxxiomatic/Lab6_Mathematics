# %% [markdown]
# ![image.png](attachment:6c077a1b-6b1a-4649-a336-340e92916644.png)

# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt

def PlotCreator(fname, gname, a, b, n, letter):
    i = 0
    if letter == 'a':
        mark1 = '-'
        mark2 = mark1
    if letter == 'b':
        mark1 = ':'
        mark2 = mark1
    if letter == 'c':
        mark1 = '-'
        mark2 = ':'
    if letter == 'd':
        mark1 = ':'
        mark2 = '-'
    x = np.linspace(a, b, n * 10)
    plt.plot(x, fname(x), mark1)
    plt.plot(x, gname(x), mark2)
    while i <= n:
        plt.vlines(x = a + i * (b - a) / n, ymin = fname(a + i * (b - a) / n), ymax = gname(a + i * (b - a) / n), color = 'r')
        i = i + 1

def funcf(x):
    return x ** 2
        
def funcg(x):
    return np.exp(x)

PlotCreator(funcf, funcg, 0, 5, 20, 'd')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:0c65ca9d-bab8-4f4d-b8c1-3271a0bd35d8.png)

# %%
# x ** 2 - y >= 1
# y = x ** 2 - 1
# x ** 2 - y >= -1
# y = x ** 2 + 1

def func1(x):
    return x ** 2 - 1

def func2(x):
    return x ** 2 + 1

PlotCreator(func1, func2, 0, 5, 20, 'd')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:148167e1-a251-4940-b3e0-e0fb88b74d4e.png)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection = '3d')

xs = np.linspace(-1, 1, 50)
ys = np.linspace(-1, 1, 50)
X, Y = np.meshgrid(xs, ys)
Z = 4 * np.sin(2 * np.pi * X) * np.cos(1.5 * Y) * (1 - X ** 2) * Y * (1 - Y)
ax.plot_wireframe(X, Y, Z, rstride = 2, cstride = 2)

# %% [markdown]
# ![image.png](attachment:2fcf8ec4-828d-422e-b6b9-ad7ffad43b28.png)

# %%
from matplotlib import cm

fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})

# Построение поверхности
surf = ax.plot_surface(X, Y, Z, cmap = cm.YlGnBu_r, linewidth = 0)

# Цветовой индикатор
fig.colorbar(surf, shrink = 0.5, aspect = 5)
plt.show()

# %% [markdown]
# ![image.png](attachment:b7a89706-b5fc-44a0-aa60-d2f5203b7cd2.png)

# %%
fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})

# Аналитическое определение поверхности
xs = np.linspace(0.1, 2, 50)
ys = np.linspace(0.1, 2, 50)
X, Y = np.meshgrid(xs, ys)
Z = 1 / X + 1 / Y

# Построение поверхности
surf = ax.plot_surface(X, Y, Z, cmap = cm.YlGnBu_r, linewidth = 0)

# Цветовой индикатор
fig.colorbar(surf, shrink = 0.5, aspect = 5)
plt.show()

# %% [markdown]
# ![image.png](attachment:b58641be-4eb7-49ed-8e65-36338c2f5d9f.png)

# %%
# EXAMPLE 3

fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})
ax.contour(X, Y, Z, cmap = cm.YlGnBu_r)
plt.show()

# %%
# EXAMPLE 4.2
# Без заливки

cs = plt.contourf(Z)

# %%
# EXAMPLE 4.1 
# С заливкой

cs = plt.contourf(Z)
plt.colorbar(cs, shrink = 0.9, aspect = 5)

# %% [markdown]
# ![image.png](attachment:2693ba10-817b-4d0f-9cea-f3a087bd78ac.png)

# %%
xs = np.linspace(0.1, 0.1035, 50)
ys = np.linspace(0.1, 0.1035, 50)
X, Y = np.meshgrid(xs, ys)
Z = 1 / X + 1 / Y

cs = plt.contourf(Z)
plt.grid(True)
plt.show()

cs = plt.contourf(Z)
plt.colorbar(cs, shrink = 0.9, aspect = 5, drawedges = True)
plt.grid(True)
plt.show()

# %% [markdown]
# ![image.png](attachment:e68c3afc-dff1-41f9-8ebd-80930ef4afe2.png)

# %%
# EXAMPLE 5

import matplotlib.pyplot as plt

xs = np.linspace(0.1, 2, 50)
ys = np.linspace(0.1, 2, 50)
X, Y = np.meshgrid(xs, ys)
Z = 1 / X + 1 / Y

fig1 = plt.figure()
ax1 = fig1.add_subplot(231, projection = '3d')
ax2 = fig1.add_subplot(232, projection = '3d')
ax3 = fig1.add_subplot(233, projection = '3d')
ax4 = fig1.add_subplot(234, projection = '3d')
ax5 = fig1.add_subplot(235, projection = '3d')
ax6 = fig1.add_subplot(236, projection = '3d')

# Построим поверхность на трёх верхних графиках
ax1.plot_surface(X, Y, Z, edgecolor = 'royalblue', lw = 0.5, rstride = 8, cstride = 8, alpha = 0.01)
ax2.plot_surface(X, Y, Z, edgecolor = 'royalblue', lw = 0.5, rstride = 8, cstride = 8, alpha = 0.01)
ax3.plot_surface(X, Y, Z, edgecolor = 'royalblue', lw = 0.5, rstride = 8, cstride = 8, alpha = 0.01)

# Построение линий уровня в разных проекциях вместе с самой поверхностью
ax1.contour(X, Y, Z, zdir = 'z', offset = -1, cmap = 'coolwarm')
ax2.contour(X, Y, Z, zdir = 'x', offset = -1, cmap = 'coolwarm')
ax3.contour(X, Y, Z, zdir = 'y', offset = 1, cmap = 'coolwarm')

# Построение линий уровня в разных проекциях отдельно от поверхности
ax4.contour(X, Y, Z, zdir = 'z', offset = -1, cmap = 'coolwarm')
ax5.contour(X, Y, Z, zdir = 'x', offset = -1, cmap = 'coolwarm')
ax6.contour(X, Y, Z, zdir = 'y', offset = 1, cmap = 'coolwarm')

plt.show()

# %%
# EXAMPLE 6

import numpy as np

t = np.linspace(-6, 6, 50)
x = np.cos(t)
y = np.sin(t)
z = t

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection = '3d')
ax.plot(x, y, z)
plt.show()

# %% [markdown]
# ![image.png](attachment:5fda3951-7455-42d0-8f21-7e8213af5099.png)
#
# ![image.png](attachment:70bf1640-ac26-462d-9f7d-7fff5f5341f3.png)

# %%
t = np.linspace(-8 * np.pi, 8 * np.pi, 50)
x = np.exp(np.abs(t)) * np.cos(2 * t)
y = 3 * np.sin(t)
z = -2 * t

fig7 = plt.figure()
ax = fig7.add_subplot(111, projection = '3d')
ax.plot(x, y, z, ':r')
plt.show()

# %%
# EXAMPLE 7

u = np.linspace(-2 * np.pi, 2 * np.pi, 50)
v = np.linspace(-2 * np.pi, 2 * np.pi, 50)
U, V = np.meshgrid(u, v)
XX = U * np.cos(V)
YY = U * np.sin(V)
ZZ = U

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection = '3d')
surf2 = ax.plot_surface(XX, YY, ZZ, cmap = cm.YlGnBu_r)
fig1.colorbar(surf2, shrink = 0.8, aspect = 5)

# %%
# EXAMPLE 8

from sympy import symbols, sin, cos
from sympy.plotting import plot3d

x, y = symbols('x y')
plot3d(cos(x) * sin(y), (x, -3, 3), (y, -3, 3))

# %% [markdown]
# ![image.png](attachment:bb3e5adc-23d1-40e2-a260-a77b5b78714a.png)
# ![image.png](attachment:ddbdb0cd-f308-42d7-996d-81f21cda8589.png)

# %%
u = np.linspace(0, 2 * np.pi, 50)
v = np.linspace(0, 2 * np.pi, 50)
U, V = np.meshgrid(u, v)
XX = 3 * np.sin(U) * np.cos(V)
YY = 2 * np.sin(V)
ZZ = np.cos(U)

fig1 = plt.figure()
ax = fig1.add_subplot(111, projection = '3d')
surf2 = ax.plot_surface(XX, YY, ZZ, cmap = "viridis", alpha = 0.25)

# %% [markdown]
# ![image.png](attachment:eb836b3d-3861-4d40-8fda-72952fc34160.png)

# %%
# A)

# 1 - x ** 2 - y ** 2 > 0
# ln y > 0
# y ** 2 < 1 - x ** 2
# y < sqrt(1 - x ** 2)
# y > - sqrt(1 - x ** 2)
# y > 1

def funcf(x):
    return np.sqrt(1 - x ** 2)

def funcg(x):
    return np.exp(0) * (x ** 0)

PlotCreator(funcf, funcg, 0, 5, 100, 'd')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.grid(True)
plt.show()

# Б)

# 4 - x ** 2 - y ** 2 >= 0
# y ** 2 = 4 - x ** 2
# y = sqrt(4 - x ** 2)
# x ** 2 + y ** 2 - 1 > 0
# y ** 2 > 1 - x ** 2
# y > sqrt(1 - x ** 2)

def funcf(x):
    return np.sqrt(4 - x ** 2)

def funcg(x):
    return np.sqrt(1 - x ** 2)

PlotCreator(funcf, funcg, 0, 5, 100, 'd')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(y = 0, color = 'k')
plt.axvline(x = 0, color = 'k')
plt.grid(True)
plt.show()
# Out:
# C:\Users\Илья\AppData\Local\Temp\ipykernel_10884\3661452719.py:11: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(1 - x ** 2)
# C:\Users\Илья\AppData\Local\Temp\ipykernel_10884\3661452719.py:34: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(4 - x ** 2)
# C:\Users\Илья\AppData\Local\Temp\ipykernel_10884\3661452719.py:37: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(1 - x ** 2)

# %% [markdown]
# ![image.png](attachment:7666b639-272f-42d7-a002-a2436e75a15a.png)

# %%
# А)
# Упражнение 2С

fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})

# Аналитическое определение поверхности
xs = np.linspace(-2 * np.pi, 2 * np.pi, 50)
ys = np.linspace(-2 * np.pi, 2 * np.pi, 50)
X, Y = np.meshgrid(xs, ys)
Z = np.cos(X * Y)

# Построение поверхности
surf = ax.plot_surface(X, Y, Z, cmap = cm.YlGnBu_r, linewidth = 0)

# Цветовой индикатор
fig.colorbar(surf, shrink = 0.5, aspect = 5)
plt.show()

# Упражнение 3C
# Строим поверхности, состоящие из линий уровня
fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})
ax.contour(X, Y, Z, cmap = cm.YlGnBu_r)
plt.show()

# Упражнение 4С
# Плоские линии уровня
cs = plt.contourf(Z)
plt.colorbar(cs, shrink = 0.9, aspect = 5)
plt.show()

# %%
# Б)
# Упражнение 2С

fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})

# Аналитическое определение поверхности
xs = np.linspace(-2 * np.pi, 2 * np.pi, 30)
ys = np.linspace(-2 * np.pi, 2 * np.pi, 30)
X, Y = np.meshgrid(xs, ys)
Z = 1 / (np.sin(X) * np.sin(Y))

# Построение поверхности
surf = ax.plot_surface(X, Y, Z, cmap = cm.YlGnBu_r, linewidth = 0)

# Цветовой индикатор
fig.colorbar(surf, shrink = 0.5, aspect = 5)
plt.show()

# Упражнение 3C
# Строим поверхности, состоящие из линий уровня
fig, ax = plt.subplots(subplot_kw = {"projection":"3d"})
ax.contour(X, Y, Z, cmap = cm.YlGnBu_r)
plt.show()

# Упражнение 4С
# Плоские линии уровня
cs = plt.contourf(Z)
plt.colorbar(cs, shrink = 0.9, aspect = 5)
plt.show()
